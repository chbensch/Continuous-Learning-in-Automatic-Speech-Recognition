# %% [markdown]
# # Load Spacy

# %%
import spacy
import pickle
import copy
import numpy as np
from tqdm import tqdm
from collections import Counter

#spacy.prefer_gpu()
nlp = spacy.load("de_dep_news_trf")
nlp.max_length = 17000000

# %% [markdown]
# # Load pre-processed Datasets

# %%
train_doc_trf_loaded = pickle.load(open("data/train_doc_trf.p", "rb"))

# %%
val_doc_trf_loaded = pickle.load(open("data/val_doc_trf.pickle", "rb"))
test_doc_trf_loaded = pickle.load(open("data/test_doc_trf.pickle", "rb"))

# %%
print("Train: ", len(train_doc_trf_loaded))
print("Val:   ", len(val_doc_trf_loaded))
print("Test:  ", len(test_doc_trf_loaded))
# Out:
# Train:  246525
# Val:    15588
# Test:   15588

# %% [markdown]
# ## Load tokenized Datasets

# %%
# TRAIN

train_tok_text = pickle.load(open("data/train_tok_text.p", "rb"))
train_tok_lemma = pickle.load(open("data/train_tok_lemma.p", "rb"))
train_nouns_text = pickle.load(open("data/train_nouns_text.p", "rb"))
train_nouns_lemma = pickle.load(open("data/train_nouns_lemma.p", "rb"))

# %% [markdown]
# # Analyze train Data

# %%
print("train words: ", len(train_tok_text))
train_words_freq = Counter(train_tok_text)
print("train words dict: ", len(train_words_freq))
# Out:
# train words:  1138469
# train words dict:  167707

# %%
train_words_freq_keys = train_words_freq.keys()

train_rare_words = {}

for i in range(1,11):
    train_rare_words[i] = []
    for word in train_words_freq_keys:
        
        if train_words_freq[word] == i:
            train_rare_words[i].append(word)
        
    print("Number of rare words " + str(i) + " : ", len(train_rare_words[i]))
# Out:
# Number of rare words 1 :  91121
# Number of rare words 2 :  27144
# Number of rare words 3 :  12429
# Number of rare words 4 :  7111
# Number of rare words 5 :  4604
# Number of rare words 6 :  3234
# Number of rare words 7 :  2433
# Number of rare words 8 :  1914
# Number of rare words 9 :  1544
# Number of rare words 10 :  1284

# %%
pickle.dump(train_rare_words, open("data/train_rare_words.p", "wb"))

# %%
train_rare_words = pickle.load(open("data/train_rare_words.p", "rb"))

# %% [markdown]
# # Analyse Test Data

# %%
test_tok_text = []
for i in tqdm(range(len(test_doc_trf_loaded))):
    test_tok_text = test_tok_text + [token.text for token in test_doc_trf_loaded[i] if(not token.is_stop and not token.is_punct)]
# Out:
# 100%|██████████| 15588/15588 [00:04<00:00, 3574.56it/s]

# %%
print("Test words: ", len(test_tok_text))
test_words_freq = Counter(test_tok_text)
print("Test words dict: ", len(test_words_freq))
# Out:
# Test words:  67545
# Test words dict:  29553

# %%
test_words_freq_keys = test_words_freq.keys()

test_only_words = []

for word in test_words_freq_keys:
    if train_words_freq[word] == 0:
        test_only_words.append(word)

print("Test only words: ", len(test_only_words))
# Out:
# Test only words:  5810

# %%
test_train_set = {}

for i in range(1,11):
    test_train_set[i] = []
    for word in train_rare_words[i]:
        if test_words_freq[word] >= 1:
            test_train_set[i].append(word)
        
    print("Number of words " + str(i) + " : ", len(test_train_set[i]))
# Out:
# Number of words 1 :  3235
# Number of words 2 :  2239
# Number of words 3 :  1538
# Number of words 4 :  1280
# Number of words 5 :  1063
# Number of words 6 :  912
# Number of words 7 :  766
# Number of words 8 :  647
# Number of words 9 :  638
# Number of words 10 :  549

# %%
pickle.dump(test_train_set, open("data/test_train_set.p", "wb"))

# %%
test_train_set = pickle.load(open("data/test_train_set.p", "rb"))

# %%
for i in range(1,11):      
    print("Number of words " + str(i) + " : ", len(test_train_set[i]))
# Out:
# Number of words 1 :  3235
# Number of words 2 :  2239
# Number of words 3 :  1538
# Number of words 4 :  1280
# Number of words 5 :  1063
# Number of words 6 :  912
# Number of words 7 :  766
# Number of words 8 :  647
# Number of words 9 :  638
# Number of words 10 :  549

# %%
index_test_train = {}

for j in range(1,11):
    index_test_train[j] = {}
    for word in test_train_set[j]:
        index_test_train[j][word] = []

# %% [markdown]
# # For each Important List create Index List for each Word

# %%
for i in tqdm(range(len(train_doc_trf_loaded))):
    word_tokens = [token.text for token in train_doc_trf_loaded[i] if(not token.is_stop and not token.is_punct)]
    for j in range(1,11):
        for word in test_train_set[j]:
            if word in word_tokens:
                index_test_train[j][word].append(i)
# Out:
# 100%|██████████| 246525/246525 [06:48<00:00, 603.30it/s]

# %%
pickle.dump(index_test_train, open("data/index_test_train.p", "wb"))

# %%
index_test_train = pickle.load(open("data/index_test_train.p", "rb"))

# %%
for i in range(1,11):
    print(f'List {i} Word count: {len(index_test_train[i])}')
# Out:
# List 1 Word count: 3235
# List 2 Word count: 2239
# List 3 Word count: 1538
# List 4 Word count: 1280
# List 5 Word count: 1063
# List 6 Word count: 912
# List 7 Word count: 766
# List 8 Word count: 647
# List 9 Word count: 638
# List 10 Word count: 549

# %% [markdown]
# # Init with 1 word list

# %%
blacklist = list(index_test_train[1].values())
blacklist = [item for sublist in blacklist for item in sublist]

# %%
print(len(blacklist))
# Out:
# 3235

# %%
# cleaned initial list
cinit = list(set(blacklist))
print("Cleaned complete length: ", len(cinit))
# Out:
# Cleaned complete length:  3193

# %%
print(blacklist)
# Out:
# [41437, 155659, 104391, 61688, 148480, 59990, 137696, 44791, 44981, 11155, 216326, 147975, 27166, 188249, 224758, 49962, 23986, 50051, 159660, 14120, 130359, 22752, 100626, 115285, 83879, 222582, 238845, 162462, 7011, 106070, 6349, 216487, 173455, 54706, 139516, 203279, 185470, 21254, 185972, 90953, 230819, 208667, 191554, 163294, 188007, 3083, 39026, 45871, 5608, 67945, 217186, 116339, 147722, 160246, 197032, 18501, 93199, 22299, 246038, 203113, 80402, 85230, 22498, 17189, 201318, 101390, 144862, 56055, 191968, 130345, 63636, 113927, 93189, 10567, 139497, 33581, 129145, 141072, 227913, 165551, 86440, 126326, 144917, 228967, 11909, 75360, 178716, 74073, 211407, 126670, 209743, 106867, 216454, 17441, 220554, 8545, 173833, 33542, 191838, 42146, 225160, 12766, 78243, 20645, 133801, 123048, 10559, 36977, 9179, 57687, 21996, 169026, 26288, 7284, 209709, 68875, 178137, 79988, 63323, 14968, 68968, 100549, 222840, 100851, 199300, 228857, 81575, 60868, 189851, 6021, 146639, 209259, 67946, 96560, 6515, 157430, 122733, 47561, 109551, 95619, 77603, 209016, 214223, 244580, 242835, 31242, 29377, 153436, 226729, 206522, 64069, 161326, 221280, 74624, 17748, 15973, 135089, 33814, 102653, 66902, 17244, 121191, 87929, 36497,
    
    deleted_List = {}
    blackListNew[list_number] = []
    
    for j in range(1, list_number + 1):
        deleted_List[j] = [] 

    for word in index_test_train[list_number]:
        deleted_counter = 0
        
        index_list_counter = {}
        
        for index in index_test_train[list_number][word]:
            index_list_counter[index] = 0
            
            if index in useBlacklist:
                deleted_counter = deleted_counter + 1
            
            for checkList in importantLists:
                for checkWord in index_test_train[checkList]:
                    for checkIndex in index_test_train[checkList][checkWord]:
                        if(checkIndex == index):
                            index_list_counter[index] = index_list_counter[index] +1
            
        for j in range(1,list_number+1):
            if deleted_counter == j:
                deleted_List[j].append(word)
                
        if deleted_counter == 0:
            indexToDelete = index
            for potentialIndex in index_list_counter:
                if(index_list_counter[potentialIndex] <= index_list_counter[indexToDelete]):
                    indexToDelete = potentialIndex
                
            blackListNew[list_number].append(indexToDelete)
            useBlacklist.append(indexToDelete)
    
    deletedMore = 0
    for j in range(2, list_number+1):
        deletedMore = deletedMore + len(deleted_List[j])
    
    for j in range(1, list_number+1):
        print(f'{j} count: {len(deleted_List[j])}')
    
    print(f'New blacklist length: {len(blackListNew[list_number])}')
    print(f'Deleted once        : {len(deleted_List[1])}')
    print(f'Deleted more        : {deletedMore}')
    print(f'Sum                 : {len(blackListNew[list_number]) + len(deleted_List[1]) + deletedMore}')
    print(f'Use Blacklist lenght: {len(useBlacklist)}')
    print("")
# Out:
# List 2 word count: 2239
# 1 count: 80
# 2 count: 1
# New blacklist length: 2158
# Deleted once        : 80
# Deleted more        : 1
# Sum                 : 2239
# Use Blacklist lenght: 5393
#
# List 3 word count: 1538
# 1 count: 86
# 2 count: 2
# 3 count: 0
# New blacklist length: 1450
# Deleted once        : 86
# Deleted more        : 2
# Sum                 : 1538
# Use Blacklist lenght: 6843
#
# List 4 word count: 1280
# 1 count: 71
# 2 count: 4
# 3 count: 0
# 4 count: 0
# New blacklist length: 1205
# Deleted once        : 71
# Deleted more        : 4
# Sum                 : 1280
# Use Blacklist lenght: 8048
#
# List 5 word count: 1063
# 1 count: 93
# 2 count: 6
# 3 count: 0
# 4 count: 0
# 5 count: 0
# New blacklist length: 964
# Deleted once        : 93
# Deleted more        : 6
# Sum                 : 1063
# Use Blacklist lenght: 9012
#
# List 10 word count: 549
# 1 count: 68
# 2 count: 5
# 3 count: 0
# 4 count: 0
# 5 count: 0
# 6 count: 0
# 7 count: 0
# 8 count: 0
# 9 count: 0
# 10 count: 0
# New blacklist length: 476
# Deleted once        : 68
# Deleted more        : 5
# Sum                 : 549
# Use Blacklist lenght: 9488

# %% [markdown]
# # Punch all Blacklists together

# %%
completeBlacklist = copy.deepcopy(blacklist)

for bList in importantLists:
    print(f'Blacklist {bList} length: {len(blackListNew[bList])}')
    completeBlacklist += blackListNew[bList]

print("complete length: ", len(completeBlacklist))
print(f'Use Blacklist lenght: {len(useBlacklist)}')
# Out:
# Blacklist 2 length: 2158
# Blacklist 3 length: 1450
# Blacklist 4 length: 1205
# Blacklist 5 length: 964
# Blacklist 10 length: 476
# complete length:  9488
# Use Blacklist lenght: 9488

# %%
# remove duplicates
cleanedCompleteBlacklist = list(set(completeBlacklist))

# sort list
completeBlacklist_sorted = copy.deepcopy(cleanedCompleteBlacklist)
completeBlacklist_sorted.sort()

print("Cleaned complete length: ", len(completeBlacklist_sorted))
# Out:
# Cleaned complete length:  9446

# %% [markdown]
# # Evaluate complete Blacklist

# %%
from collections import Counter

useBlacklist = copy.deepcopy(completeBlacklist_sorted)

for list_number in importantLists:
    print(f'List {list_number} word count: {len(index_test_train[list_number])}')
    
    deleted_List = {}
    
    for j in range(1, list_number + 1):
        deleted_List[j] = [] 

    for word in index_test_train[list_number]:
        deleted_counter = 0
                
        for index in index_test_train[list_number][word]:         
            if index in useBlacklist:
                deleted_counter = deleted_counter + 1
            
        for j in range(1,list_number+1):
            if deleted_counter == j:
                deleted_List[j].append(word)                
    
    deletedMore = 0
    for j in range(2, list_number+1):
        deletedMore = deletedMore + len(deleted_List[j])
    
    for j in range(1, 3):
        print(f'{j} count: {len(deleted_List[j])}')
    
    print(f'Deleted once : {len(deleted_List[1])}')
    print(f'Deleted more : {deletedMore}')
    print(f'%            : {deletedMore / len(deleted_List[1])}')
    print(f'Sum          : {len(deleted_List[1]) + deletedMore}')
    print("")
# Out:
# List 2 word count: 2239
# 1 count: 2233
# 2 count: 6
# Deleted once : 2233
# Deleted more : 6
# %            : 0.0026869682042095834
# Sum          : 2239
#
# List 3 word count: 1538
# 1 count: 1536
# 2 count: 2
# Deleted once : 1536
# Deleted more : 2
# %            : 0.0013020833333333333
# Sum          : 1538
#
# List 4 word count: 1280
# 1 count: 1276
# 2 count: 4
# Deleted once : 1276
# Deleted more : 4
# %            : 0.003134796238244514
# Sum          : 1280
#
# List 5 word count: 1063
# 1 count: 1057
# 2 count: 6
# Deleted once : 1057
# Deleted more : 6
# %            : 0.005676442762535478
# Sum          : 1063
#
# List 10 word count: 549
# 1 count: 544
# 2 count: 5
# Deleted once : 544
# Deleted more : 5
# %            : 0.009191176470588236
# Sum          : 549

# %%
pickle.dump(completeBlacklist_sorted, open("data/completeBlacklist.p", "wb"))

# %%
completeBlacklist = pickle.load(open("data/completeBlacklist.p", "rb"))

# %%
print(len(completeBlacklist))
# Out:
# 9446

# %%
print(completeBlacklist)
# Out:
# [82, 83, 158, 215, 226, 245, 350, 381, 434, 450, 533, 597, 613, 644, 659, 677, 690, 818, 862, 996, 1043, 1081, 1182, 1238, 1264, 1297, 1310, 1327, 1358, 1390, 1504, 1521, 1530, 1566, 1587, 1596, 1633, 1822, 1916, 1936, 1954, 1967, 1995, 2052, 2172, 2204, 2235, 2248, 2258, 2351, 2429, 2437, 2442, 2451, 2481, 2585, 2613, 2689, 2691, 2861, 2910, 2946, 2972, 3083, 3285, 3287, 3344, 3346, 3431, 3544, 3701, 3746, 3777, 3874, 4066, 4152, 4198, 4234, 4366, 4409, 4415, 4513, 4603, 4641, 4701, 4767, 4894, 5050, 5053, 5113, 5322, 5410, 5427, 5456, 5474, 5479, 5498, 5519, 5608, 5696, 5767, 5772, 5826, 5831, 5905, 5919, 5933, 5939, 5957, 6005, 6021, 6082, 6247, 6316, 6349, 6493, 6502, 6512, 6515, 6553, 6640, 6643, 6655, 6694, 6709, 6773, 6845, 6
zzeichen': [9589], 'kugelkopf': [9596], 'stoffwechselweg': [9665], 'aeronautica': [9718], 'knautschzone': [9784], 'vw': [9983], 'kursieren': [10114], 'alix': [10146], 'schallmauer': [10192], 'sms': [10249], 'vielsagenden': [10249], 'hdgdl': [10249], 'lies': [10258], 'kaiserwetter': [10311], 'schwärmte': [10311], 'bräunung': [10485], 'traumatisieren': [10503], 'milchig': [10738], 'schufa': [10812], 'charismatischer': [10890], 'kunstraum': [11002], 'sprachbund': [11033], 'weißlichen': [11055], 'computervirus': [11129], 'quartal': [11156], 'waschbecken': [11158], 'holzverbrenn ...

# %% [markdown]
# # Load real datasets

# %%
from datasets import load_from_disk

test_sampled_pro = load_from_disk("/mnt/e/Master/data/test_sampled_pro")
train_sampled_pro = load_from_disk("/mnt/e/Master/data/train_sampled_pro")

# %%
train_text_raw = load_from_disk("/mnt/e/Master/data/0_text/train_text")

# %% [markdown]
# ### Verify to delete only the relevant data

# %%
print(train_text_raw[0])
print("")
print(train_text_raw[158])
print(train_text_raw[160])
print(train_text_raw[161])
print("")
print(train_text_raw[215])
print(train_text_raw[218])
print(train_text_raw[219])
print("")
print(train_text_raw[226])
print(train_text_raw[230])
print(train_text_raw[231])
print("")
print(train_text_raw[246524])
# Out:
# {'sentence': 'aber wir verstehen ja die haushaltslage '}
#
# {'sentence': 'der tauernbach durchfließt vor allem schichten kristallinen schiefers des tauernfensters '}
# {'sentence': 'der neu geschaffene schutzbereich vor den schleusen zog fischer aus der umgebung an '}
# {'sentence': 'bezirk nahe dem unteren belvedere '}
#
# {'sentence': 'korrektes trockenes fundament mit harten hufen '}
# {'sentence': 'auch erwachsene sollen häufig interesse an den ausführungen zeigen '}
# {'sentence': 'zu den besonderen toren zählen abschlüsse mit der hacke oberschenkel schulter usw '}
#
# {'sentence': 'sie erscheint im böhlau verlag '}
# {'sentence': 'dies tut man in form von ipadressen '}
# {'sentence': 'dabei betonten gnesiolutheraner und philippisten gemeinsam die zugerechnete gerechtigkeit '}
#
# {'sentence': 'er ist nicht verheiratet und neben dem polosport auch als pferdezüchter tätig '}

# %%
print(len(train_sampled_pro))
print(len(train_text_raw))
print(len(completeBlacklist))
print(len(completeBlacklist) / len(train_text_raw))
# Out:
# 246525
# 246525
# 9446
# 0.03831660075043099

# %%
dumpList = []

for i in range(0,len(train_text_raw)):
    dumpList.append(i)
    
print(dumpList[158])
print(dumpList[215])
print(dumpList[226])

keepList = list(set(dumpList)-set(completeBlacklist))

print(len(keepList))

print(keepList[158])
print(keepList[215])
print(keepList[226])
# Out:
# 158
# 215
# 226
# 237079
# 161
# 219
# 231

# %% [markdown]
# ### 158 --> 161 ; 215 --> 219 ; 226 --> 231 works!
# Try it on the huggingface text dataset

# %%
train_text_raw_cut = train_text_raw.select(keepList)

# %%
print(len(train_text_raw))
print(len(completeBlacklist))
print(len(train_text_raw) - len(completeBlacklist))
print(len(train_text_raw_cut))
# Out:
# 246525
# 9446
# 237079
# 237079

# %%
print(train_text_raw_cut[0])
print("")
print(train_text_raw_cut[158])
print(train_text_raw_cut[160])
print(train_text_raw_cut[161])
print("")
print(train_text_raw_cut[215])
print(train_text_raw_cut[218])
print(train_text_raw_cut[219])
print("")
print(train_text_raw_cut[226])
print(train_text_raw_cut[230])
print(train_text_raw_cut[231])
print("")
print(train_text_raw_cut[246525-len(completeBlacklist)-1])
# Out:
# {'sentence': 'aber wir verstehen ja die haushaltslage '}
#
# {'sentence': 'bezirk nahe dem unteren belvedere '}
# {'sentence': 'das erste kapitel behandelt bestimmungen zu diesen drei festen '}
# {'sentence': 'die südlichen kreise ostwestfalens liegen im bezirk des landgerichts paderborn '}
#
# {'sentence': 'zu den besonderen toren zählen abschlüsse mit der hacke oberschenkel schulter usw '}
# {'sentence': 'bei der soliden kompression hingegen kann durchgängig dasselbe wörterbuch für alle dateien verwendet werden '}
# {'sentence': 'in der kleinstadt selbst haben sich kleinere handelsgeschäfte sowie handwerks und dienstleistungsbetriebe angesiedelt '}
#
# {'sentence': 'dabei betonten gnesiolutheraner und philippisten gemeinsam die zugerechnete gerechtigkeit '}
# {'sentence': 'mills benutzt einen lakonischen stil er verwendet kurze sätze und viele dialoge '}
# {'sentence': 'zwischenzeitlich war er kunstlehrer an der amerikanischen schule in bremerhaven '}
#
# {'sentence': 'er ist nicht verheiratet und neben dem polosport auch als pferdezüchter tätig '}

# %%
train_text_raw_cut.save_to_disk("/mnt/e/Master/data/0_text/train_text_cut")

# %%
train_text_raw_cut_loaded = load_from_disk("/mnt/e/Master/data/0_text/train_text_cut_copy")

# %%
print(train_text_raw_cut_loaded[0])
print("")
print(train_text_raw_cut_loaded[158])
print(train_text_raw_cut_loaded[160])
print(train_text_raw_cut_loaded[161])
print("")
print(train_text_raw_cut_loaded[215])
print(train_text_raw_cut_loaded[218])
print(train_text_raw_cut_loaded[219])
print("")
print(train_text_raw_cut_loaded[226])
print(train_text_raw_cut_loaded[230])
print(train_text_raw_cut_loaded[231])
print("")
print(train_text_raw_cut_loaded[246525-len(completeBlacklist)-1])
# Out:
# {'sentence': 'aber wir verstehen ja die haushaltslage '}
#
# {'sentence': 'bezirk nahe dem unteren belvedere '}
# {'sentence': 'das erste kapitel behandelt bestimmungen zu diesen drei festen '}
# {'sentence': 'die südlichen kreise ostwestfalens liegen im bezirk des landgerichts paderborn '}
#
# {'sentence': 'zu den besonderen toren zählen abschlüsse mit der hacke oberschenkel schulter usw '}
# {'sentence': 'bei der soliden kompression hingegen kann durchgängig dasselbe wörterbuch für alle dateien verwendet werden '}
# {'sentence': 'in der kleinstadt selbst haben sich kleinere handelsgeschäfte sowie handwerks und dienstleistungsbetriebe angesiedelt '}
#
# {'sentence': 'dabei betonten gnesiolutheraner und philippisten gemeinsam die zugerechnete gerechtigkeit '}
# {'sentence': 'mills benutzt einen lakonischen stil er verwendet kurze sätze und viele dialoge '}
# {'sentence': 'zwischenzeitlich war er kunstlehrer an der amerikanischen schule in bremerhaven '}
#
# {'sentence': 'er ist nicht verheiratet und neben dem polosport auch als pferdezüchter tätig '}

# %% [markdown]
# # works on the text dataset --> cut real train set

# %%
train_sampled_pro_cut = train_sampled_pro.select(keepList)

# %%
train_sampled_pro_cut.save_to_disk("/mnt/e/Master/data/train_sampled_pro_cut")
